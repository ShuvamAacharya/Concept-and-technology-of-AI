# %% [markdown]
# task1

# %%
temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5,
                16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3,
                13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7,
                7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3,
                16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5]

cold = []
mild = []
comfort = []

for temp in temperatures:
    if temp < 10:
        cold.append(temp)
    elif 10 <= temp <= 15:
        mild.append(temp)
    elif 15 <= temp < 20:
        comfort.append(temp)

print("Cold:", cold)
print("Mild:", mild)
print("Comfort:", comfort)
# Out:
# Cold: [8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# Mild: [14.1, 13.5, 13.0, 12.9, 13.3, 14.0, 13.4, 14.2, 12.8, 13.7, 13.6, 13.8, 13.9, 12.7, 13.1, 12.5]
# Comfort: [17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]

# %% [markdown]
# task2

# %%
cold_temperature_count =len(cold)
mild_temperature_count =len(mild)
comfort_temperature_count =len(comfort)

print(f"It was cold {cold_temperature_count} times.")
print(f"it was mild {mild_temperature_count} times.")
print(f"it was comfort {comfort_temperature_count} times.")
# Out:
# It was cold 16 times.
# it was mild 16 times.
# it was comfort 16 times.

# %% [markdown]
# task3

# %%
temperatures_fahrenheit=[]
for celsius_temperature in temperatures:
    fahrenheit_temperature=(celsius_temperature *9/5)+32
    temperatures_fahrenheit.append(fahrenheit_temperature)
print("Temperature in fahrenheit:",temperatures_fahrenheit)
# Out:
# Temperature in fahrenheit: [46.76, 63.32, 57.379999999999995, 46.22, 64.4, 56.3, 48.2, 64.04, 55.4, 47.3, 61.7, 55.22, 45.86, 62.959999999999994, 55.94, 47.120000000000005, 62.059999999999995, 57.2, 49.1, 64.94, 56.120000000000005, 46.58, 64.22, 57.56, 45.68, 62.6, 55.04, 46.4, 62.24, 56.66, 46.04, 63.5, 56.48, 47.66, 62.78, 56.84, 48.56, 64.58, 57.02, 46.94, 61.519999999999996, 54.86, 48.02, 64.75999999999999, 55.58, 46.04, 61.88, 54.5]

# %% [markdown]
# task4

# %%
import matplotlib.pyplot as plt
temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5,
                16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3,
                13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7,
                7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3,
                16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5]
night=[]
morning=[]
day=[]
for i in range(0,len(temperatures),3):
    night.append(temperatures[i])
    morning.append(temperatures[i+1])
    day.append(temperatures[i+2])
avg_day_temp=sum(day)/len(day)
print(f"Avg day-time temp:{avg_day_temp:.2f}C")

plt.plot(range(1,len(day)+1),day,marker='o',label="Day Temp",color="blue")
plt.title("Day VS Temperature")
plt.xlabel("Day")
plt.ylabel("Temperature(°C)")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Avg day-time temp:13.41C
